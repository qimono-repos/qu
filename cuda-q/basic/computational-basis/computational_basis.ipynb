# %% [markdown]
# # Computational Basis
#
# The computational basis for a single qubit consists of $|0\rangle$ and $|1\rangle$.
#
# - $|0\rangle$: qubit is in the ground state (measured as `0`)
# - $|1\rangle$: qubit is in the excited state (measured as `1`), achieved by applying an X gate to $|0\rangle$

# %%
import cudaq


@cudaq.kernel
def zero_state():
    qubit = cudaq.qvector(1)


@cudaq.kernel
def one_state():
    qubit = cudaq.qvector(1)
    x(qubit[0])


print("=== |0> state ===")
result_zero = cudaq.sample(zero_state, shots_count=1000)
for bitstring, count in result_zero.items():
    print(f"  |{bitstring}>: {count}")

print("\n=== |1> state ===")
result_one = cudaq.sample(one_state, shots_count=1000)
for bitstring, count in result_one.items():
    print(f"  |{bitstring}>: {count}")
